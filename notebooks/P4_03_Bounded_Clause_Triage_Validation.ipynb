# %% [markdown]
# <a href="https://colab.research.google.com/github/icmsol/capstone-project-7-integrated-ai-systems-synthesis/blob/main/notebooks/P4_03_Bounded_Clause_Triage_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/icmsol/capstone-project-7-integrated-ai-systems-synthesis/blob/main/notebooks/P4_03_Bounded_Clause_Triage_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # P4-03 — Bounded Clause-Theme Inference Validation
#
# Use the standard CPU runtime. The output is triage only and does not constitute legal interpretation or a final decision.

# %%
import shutil, subprocess
from pathlib import Path
repo = Path('/content/capstone-project-7-integrated-ai-systems-synthesis')
if repo.exists(): shutil.rmtree(repo)
subprocess.run([
    'git', 'clone', '--depth', '1',
    'https://github.com/icmsol/capstone-project-7-integrated-ai-systems-synthesis.git',
    str(repo),
], check=True)
print(repo)
# Out:
# /content/capstone-project-7-integrated-ai-systems-synthesis

# %%
import subprocess, sys
subprocess.run([
    sys.executable, '-m', 'pip', 'install', '-q',
    '-r', str(repo / 'requirements_p4_03.txt')
], check=True)
print('Dependencies installed.')
# Out:
# Dependencies installed.

# %%
result = subprocess.run([
    sys.executable,
    str(repo / 'tests' / 'run_p4_03_validation.py')
], cwd=repo, text=True, capture_output=True)
print(result.stdout)
if result.stderr: print(result.stderr)
result.check_returncode()
# Out:
# Actual Project 4 predictions: 3
# PASSAGE-AUDIT-001: Audit Rights / 0.999961 / escalate / domain_warning=True / truncated=False
# PASSAGE-ASSIGNMENT-001: Anti-Assignment / 0.999966 / escalate / domain_warning=True / truncated=False
# PASSAGE-LONG-001: Audit Rights / 0.999957 / escalate / domain_warning=True / truncated=True
# Integrated case-state validation: PASS
# Audit hash-chain continuation: PASS
# External actions performed: 0
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/transformer.py:531: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at /pytorch/aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
